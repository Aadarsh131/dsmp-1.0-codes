# %%
import pandas as pd
print(pd.__version__)

a = [1, 7, 2]

#Series and DataFrame
myvar = pd.Series(a, index = ['a','b','c'])
myvar_df = pd.DataFrame(myvar)

print(myvar)
print(myvar_df)
print(type(myvar))
print(type(myvar_df))
# Out:
# 2.3.2
# a    1
# b    7
# c    2
# dtype: int64
#    0
# a  1
# b  7
# c  2
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
dates = pd.date_range('20250918', periods=6)
dates, type(dates)
# Out:
# (DatetimeIndex(['2025-09-18', '2025-09-19', '2025-09-20', '2025-09-21',
#                 '2025-09-22', '2025-09-23'],
#                dtype='datetime64[ns]', freq='D'),
#  pandas.core.indexes.datetimes.DatetimeIndex)

# %%
import numpy as np

df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2025-09-18  2.899734  0.716522 -0.324855  0.459091
# 2025-09-19 -0.495171  0.398830 -1.814548  0.757465
# 2025-09-20  0.734860  1.115458  0.431553 -1.087417
# 2025-09-21 -0.363537 -0.584545 -0.281200  1.317912
# 2025-09-22 -1.116825  0.480557 -0.394098 -1.541407
# 2025-09-23 -0.745400  0.258417 -1.256063  0.425718

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": list([(3,),4,'s',.4]),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
        "PresentDate": pd.Series(pd.date_range('20250918', periods=4))
    }
)
df2, df2.index, df2.columns
# Out:
# (     A          B    C     D      E    F PresentDate
#  0  1.0 2013-01-02  1.0  (3,)   test  foo  2025-09-18
#  1  1.0 2013-01-02  1.0     4  train  foo  2025-09-19
#  2  1.0 2013-01-02  1.0     s   test  foo  2025-09-20
#  3  1.0 2013-01-02  1.0   0.4  train  foo  2025-09-21,
#  Index([0, 1, 2, 3], dtype='int64'),
#  Index(['A', 'B', 'C', 'D', 'E', 'F', 'PresentDate'], dtype='object'))

# %%
df2.to_numpy(), df2.dtypes, df2.describe()
# Out:
# (array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, (3,), 'test', 'foo',
#          Timestamp('2025-09-18 00:00:00')],
#         [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 4, 'train', 'foo',
#          Timestamp('2025-09-19 00:00:00')],
#         [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 's', 'test', 'foo',
#          Timestamp('2025-09-20 00:00:00')],
#         [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 0.4, 'train', 'foo',
#          Timestamp('2025-09-21 00:00:00')]], dtype=object),
#  A                     float64
#  B               datetime64[s]
#  C                     float32
#  D                      object
#  E                    category
#  F                      object
#  PresentDate    datetime64[ns]
#  dtype: object,
#           A                    B    C          PresentDate
#  count  4.0                    4  4.0                    4
#  mean   1.0  2013-01-02 00:00:00  1.0  2025-09-19 12:00:00
#  min    1.0  2013-01-02 00:00:00  1.0  2025-09-18 00:00:00
#  25%    1.0  2013-01-02 00:00:00  1.0  2025-09-18 18:00:00
#  50%    1.0  2013-01-02 00:00:00  1.0  2025-09-19 12:00:00
#  75%    1.0  2013-01-02 00:00:00  1.0  2025-09-20 06:00:00
#  max    1.0  2013-01-02 00:00:00  1.0  2025-09-21 00:00:00
#  std    0.0                  NaN  0.0                  NaN)

# %%
df, df['A'], df.A, df.A[0:2]
# Out:
# (                   A         B         C         D
#  2025-09-18  2.899734  0.716522 -0.324855  0.459091
#  2025-09-19 -0.495171  0.398830 -1.814548  0.757465
#  2025-09-20  0.734860  1.115458  0.431553 -1.087417
#  2025-09-21 -0.363537 -0.584545 -0.281200  1.317912
#  2025-09-22 -1.116825  0.480557 -0.394098 -1.541407
#  2025-09-23 -0.745400  0.258417 -1.256063  0.425718,
#  2025-09-18    2.899734
#  2025-09-19   -0.495171
#  2025-09-20    0.734860
#  2025-09-21   -0.363537
#  2025-09-22   -1.116825
#  2025-09-23   -0.745400
#  Freq: D, Name: A, dtype: float64,
#  2025-09-18    2.899734
#  2025-09-19   -0.495171
#  2025-09-20    0.734860
#  2025-09-21   -0.363537
#  2025-09-22   -1.116825
#  2025-09-23   -0.745400
#  Freq: D, Name: A, dtype: float64,
#  2025-09-18    2.899734
#  2025-09-19   -0.495171
#  Freq: D, Name: A, dtype: float64)

# %%
df.loc[dates[0]], df.loc[dates[:2]], df.loc[:,['A','B']]
# Out:
# (A    2.899734
#  B    0.716522
#  C   -0.324855
#  D    0.459091
#  Name: 2025-09-18 00:00:00, dtype: float64,
#                     A         B         C         D
#  2025-09-18  2.899734  0.716522 -0.324855  0.459091
#  2025-09-19 -0.495171  0.398830 -1.814548  0.757465,
#                     A         B
#  2025-09-18  2.899734  0.716522
#  2025-09-19 -0.495171  0.398830
#  2025-09-20  0.734860  1.115458
#  2025-09-21 -0.363537 -0.584545
#  2025-09-22 -1.116825  0.480557
#  2025-09-23 -0.745400  0.258417)

# %%
df.loc['20250918':'20250921'],df.at[dates[0], 'A']
# Out:
# (                   A         B         C         D
#  2025-09-18  2.899734  0.716522 -0.324855  0.459091
#  2025-09-19 -0.495171  0.398830 -1.814548  0.757465
#  2025-09-20  0.734860  1.115458  0.431553 -1.087417
#  2025-09-21 -0.363537 -0.584545 -0.281200  1.317912,
#  np.float64(2.89973367972189))

# %%
df.iloc[[1,4],[0,3]], df.iloc[1:4, 0:3], df.iloc[1:4], df.iloc[2,2]
# Out:
# (                   A         D
#  2025-09-19 -0.495171  0.757465
#  2025-09-22 -1.116825 -1.541407,
#                     A         B         C
#  2025-09-19 -0.495171  0.398830 -1.814548
#  2025-09-20  0.734860  1.115458  0.431553
#  2025-09-21 -0.363537 -0.584545 -0.281200,
#                     A         B         C         D
#  2025-09-19 -0.495171  0.398830 -1.814548  0.757465
#  2025-09-20  0.734860  1.115458  0.431553 -1.087417
#  2025-09-21 -0.363537 -0.584545 -0.281200  1.317912,
#  np.float64(0.43155283457745536))

# %%
df[df['A']>0], df[df>1.2]
# Out:
# (                   A         B         C         D
#  2025-09-18  2.899734  0.716522 -0.324855  0.459091
#  2025-09-20  0.734860  1.115458  0.431553 -1.087417,
#                     A   B   C         D
#  2025-09-18  2.899734 NaN NaN       NaN
#  2025-09-19       NaN NaN NaN       NaN
#  2025-09-20       NaN NaN NaN       NaN
#  2025-09-21       NaN NaN NaN  1.317912
#  2025-09-22       NaN NaN NaN       NaN
#  2025-09-23       NaN NaN NaN       NaN)

# %%
dfc = df.copy()

dfc['E'] = [3,4,3,5,4,5]
dfc[dfc['E'].isin([3,5])], dfc[dfc['E'].isin([4])]
# Out:
# (                   A         B         C         D  E
#  2025-09-18  2.899734  0.716522 -0.324855  0.459091  3
#  2025-09-20  0.734860  1.115458  0.431553 -1.087417  3
#  2025-09-21 -0.363537 -0.584545 -0.281200  1.317912  5
#  2025-09-23 -0.745400  0.258417 -1.256063  0.425718  5,
#                     A         B         C         D  E
#  2025-09-19 -0.495171  0.398830 -1.814548  0.757465  4
#  2025-09-22 -1.116825  0.480557 -0.394098 -1.541407  4)
